# %% [markdown]
# **Nama : Novela Eka Saputri**

# %% [markdown]
# **NPM : 2420506040**

# %% [markdown]
# **Rombel : 3**

# %% [markdown]
# # Soal UTS Pratikum Algoritma 2024

# %% [markdown]
# ![WhatsApp Image 2024-10-04 at 07.15.17_e2e0a8a6.jpg](data:image/jpeg;base64,...)

# %%
NPM = int(input("Masukkan NPM :"))
genap = 0
ganjil = 1

for digit in str(NPM):
  if NPM % 2 == 0:
    genap +=1
  else:
    ganjil +=1

print("Jumlah NPM Genap:", genap)
print("Jumlah NPM Ganjil:", ganjil)
# Out:
# Masukkan NPM :2420506040
# Jumlah NPM Genap: 10
# Jumlah NPM Ganjil: 1

# %%
n = int(input("Masukkan Angka : "))
for i in range(1, n + 1):
   for j in range(1, i + 1):
      print(i * j, end=" ")

   print()
# Out:
# Masukkan Angka : 4
# 1
# 2 4
# 3 6 9
# 4 8 12 16
